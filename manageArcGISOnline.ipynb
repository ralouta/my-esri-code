# %%
from arcgis.gis import GIS
from arcgis.features import FeatureLayerCollection
from arcgis.features import GeoAccessor

from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

import getpass # library to get dynamically input AGOL Password

# %%
class ArcGISDataAnalyzer:
    def __init__(self, target_date):
        self.password = getpass.getpass("Please enter your ArcGIS Online password: ") #Prompt the user to enter ArcGIS Online Password # password parameter to prompt user for ArcGIS Online password
        self.gis = GIS("https://esriaiddev.maps.arcgis.com/", "ralouta.aiddev", self.password)  # Initialize the GIS instance
        self.target_date = datetime.strptime(target_date, "%Y-%m-%d").date()
        self.items_before_date_all_users_df = None
        self.sorted_user_details = None
        
        self.sorted_user_details = None
        
    # Define a function to calculate credits per month based on item type and size
    def _calculate_credits_per_month(self, item_type, item_size):
        if item_type == 'Feature Service':
            credits_per_10mb = 2.4
            credits_per_month = (item_size / 10) * credits_per_10mb
        elif item_type == 'Tiled Imagery':
            credits_per_gb = 1.2
            credits_per_month = (item_size / 1024) * credits_per_gb
        elif item_type == 'Dynamic Imagery':
            num_images = 100  # Example number of images
            if num_images <= 10:
                credits_per_day = 10
            elif num_images <= 100:
                credits_per_day = 20
            elif num_images <= 1000:
                credits_per_day = 40
            elif num_images <= 10000:
                credits_per_day = 80
            elif num_images <= 100000:
                credits_per_day = 160
            else:
                credits_per_day = 320
            credits_per_month = (credits_per_day * 30)  # Assuming 30 days in a month
        else:
            credits_per_month = (item_size / 10) * 2.4  # Default value if item type is not found
        return credits_per_month

    def get_items_before_date_all_users(self):
        
        # Retrieve all users in the organization
        all_users = self.gis.users.search(query="*")  # You can modify the query as needed

        # Create a list to store item information
        all_items = []

        # Iterate through each user and retrieve their items
        for user in all_users:
            user_items = user.items()
            for item in user_items:
                # Convert timestamp to datetime
                last_viewed = item.lastViewed
                if last_viewed == -1:
                    last_viewed = datetime.utcfromtimestamp(0)  # Set to epoch time
                else:
                    last_viewed = datetime.fromtimestamp(last_viewed / 1000)  # Convert milliseconds to seconds

                # Convert datetime to ArcGIS Online format date (e.g., "yyyy-mm-ddTHH:mm:ssZ")
                last_viewed_agol_format = last_viewed.strftime("%Y-%m-%d")

                if last_viewed.date() <= self.target_date:
                    # Calculate credits per month based on item type and size
                    item_type = item.type  # Assuming the 'type' attribute is present in the item object
                    item_size = item.size / (1024 * 1024)  # Convert bytes to megabytes
                    credits_per_month = self._calculate_credits_per_month(item_type, item_size)

                    item_info = {
                        "item_name": item.title,
                        "item_id": item.itemid,
                        "item_url": item.url,
                        "last_viewed_date": last_viewed_agol_format,
                        "username": user.username,
                        "full_name": user.fullName,
                        "email": user.email,
                        "item_size_mb": item_size,
                        "item_type": item_type,
                        "estimated_credits_per_month": credits_per_month,
                        "estimated_cost_per_month": credits_per_month * 0.1
                    }
                    all_items.append(item_info)

        # Convert the list of items to a pandas DataFrame
        items_df = pd.DataFrame(all_items)

        return items_df

    def get_sorted_user_details(self):
        # Use self.gis to access the GIS instance
        gis = self.gis
        items_before_date_all_users_df = self.get_items_before_date_all_users()
        # Extract unique usernames
        unique_usernames = items_before_date_all_users_df['username'].unique()

        # Group the DataFrame by 'username' and calculate the total counts of items owned by each user
        user_item_counts = items_before_date_all_users_df.groupby('username')['item_id'].count()

        # Group the DataFrame by 'username' and sum the estimated credits per month, item size, and estimated cost per month for each user
        user_aggregated_data = items_before_date_all_users_df.groupby('username').agg({
            'estimated_credits_per_month': 'sum',
            'item_size_mb': 'sum',
            'estimated_cost_per_month': 'sum'
        })

        # Create a list to store user details including last login date, full name, email, item counts, total credit cost, total item size, and total cost per month
        user_details_list = []

        # Iterate through unique usernames and query the last login date, full name, email address, item counts, total credit cost, total item size, and total cost per month for each user
        for username in unique_usernames:
            user = gis.users.get(username)
            last_login_date_str = (datetime.fromtimestamp(user.lastLogin / 1000)).strftime("%Y-%m-%d")
            item_count = user_item_counts.get(username, 0)
            total_credits = user_aggregated_data.loc[username, 'estimated_credits_per_month']
            total_item_size_mb = user_aggregated_data.loc[username, 'item_size_mb']
            total_cost_per_month = user_aggregated_data.loc[username, 'estimated_cost_per_month']
            user_details = {
                "username": username,
                "last_login_date": last_login_date_str,
                "full_name": user.fullName,
                "email": user.email,
                "item_count": item_count,
                "total_credits": total_credits,
                "total_item_size_mb": total_item_size_mb,
                "total_cost_per_month": total_cost_per_month
            }
            user_details_list.append(user_details)

        # Sort the user details list by highest total cost per month
        sorted_user_details = sorted(user_details_list, key=lambda x: x['total_cost_per_month'], reverse=True)

        return pd.DataFrame(sorted_user_details)
    
    def get_users_before_target_date(self, items_df):
        
        # Convert the target_date to a datetime object
        target_date_dt = pd.to_datetime(self.target_date)
        
        # Calculate the adjusted target date by subtracting 6 months
        adjusted_target_date = target_date_dt - pd.DateOffset(months=6)
        
        # Get the sorted user details
        sorted_user_details = self.get_sorted_user_details()

        # Initialize a list to store usernames with dates before the adjusted_target_date
        usernames_before_date = []
        
        # Loop through the sorted_user_details
        for user_info in sorted_user_details:
            # Convert the last_login_date in the user_info to a datetime object
            last_login_date = pd.to_datetime(user_info['last_login_date'])
            
            # Check if the last_login_date is before the adjusted_target_date
            if last_login_date < adjusted_target_date:
                usernames_before_date.append(user_info)
        
        return usernames_before_date

# %%
# Create an instance of the ArcGISDataAnalyzer class with target date "2023-01-01"
analyzer = ArcGISDataAnalyzer("2023-01-01")

# Call the get_items_before_date_all_users() method on the analyzer instance
items_df = analyzer.get_items_before_date_all_users()

items_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\_auth\_token.py in token(self)
#     801                 if self._response_type == "token":
# --> 802                     self._init_response_type_token()
#     803                 else:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\_auth\_token.py in _init_response_type_token(self)
#     571             raise ArcGISLoginError()
# --> 572         callback_url = response.headers["location"]
#     573         if callback_url.find("acceptTermsAndConditions") > -1:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\structures.py in __getitem__(self, key)
#      51     def __getitem__(self, key):
# ---> 52         return self._store[key.lower()][1]
#      53
#
# KeyError: 'location'
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\_auth\_token.py in _init_token_auth_handshake(self)
#     643                 try:
# --> 644                     oauth_info = json.loads(js_object)
#     645                 except:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\json\decoder.py in raw_decode(self, s, idx)
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 669 (char 668)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1469
# -> 1470                     resp = self._session.post(
#    1471                         url=url,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\api.py in post(self, url, data, json, **kwargs)
#     487             redirects = self.allow_redirects
# --> 488         return self._session.post(
#     489             url,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     634
# --> 635         return self.request("POST", url, data=data, json=json, **kwargs)
#     636
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     572         )
# --> 573         prep = self.prepare_request(req)
#     574
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     483         p = PreparedRequest()
# --> 484         p.prepare(
#     485             method=request.method.upper(),
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     371         self.prepare_body(data, files, json)
# --> 372         self.prepare_auth(auth, url)
#     373
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\models.py in prepare_auth(self, auth, url)
#     602             # Allow auth to make its changes.
# --> 603             r = auth(self)
#     604
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\_auth\_token.py in __call__(self, r)
#     817         if self.legacy == False:
# --> 818             r.headers["X-Esri-Authorization"] = f"Bearer {self.token}"
#     819         elif self.legacy and r.method == "GET":
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\_auth\_token.py in token(self)
#     807             self._auth_token = None
# --> 808             self._init_token_auth_handshake()
#     809             if self._auth_token:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\_auth\_token.py in _init_token_auth_handshake(self)
#     645                 except:
# --> 646                     oauth_info = json.loads(js_object + "}")
#     647                 break
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\json\decoder.py in raw_decode(self, s, idx)
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 669 (char 668)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18564\2326240603.py in <cell line: 2>()
#       1 # Create an instance of the ArcGISDataAnalyzer class with target date "2023-01-01"
# ----> 2 analyzer = ArcGISDataAnalyzer("2023-01-01")
#       3
#       4 # Call the get_items_before_date_all_users() method on the analyzer instance
#       5 items_df = analyzer.get_items_before_date_all_users()
#
# ~\AppData\Local\Temp\ipykernel_18564\3381353065.py in __init__(self, target_date)
#       2     def __init__(self, target_date):
#       3         self.password = getpass.getpass("Please enter your ArcGIS Online password: ") #Prompt the user to enter ArcGIS Online Password # password parameter to prompt user for ArcGIS Online password
# ----> 4         self.gis = GIS("https://esriaiddev.maps.arcgis.com/", "ralouta.aiddev", self.password)  # Initialize the GIS instance
#       5         self.target_date = datetime.strptime(target_date, "%Y-%m-%d").date()
#       6         self.items_before_date_all_users_df = None
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in __init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     583                 )
#     584             else:
# --> 585                 raise e
#     586         try:
#     587             if (
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in __init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     522             self._expiration = 60
#     523         try:
# --> 524             self._portal = _portalpy.Portal(
#     525                 self._url,
#     526                 self._username,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_portalpy.py in __init__(self, url, username, password, key_file, cert_file, expiration, referer, proxy_host, proxy_port, connection, workdir, tokenurl, verify_cert, client_id, custom_auth, token, **kwargs)
#     230                 )
#     231         # self.get_version(True)
# --> 232         self.get_properties(True)
#     233
#     234     def add_group_users(
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_portalpy.py in get_properties(self, force)
#    1300                     )  # issue seen with key, cert auth
#    1301                 if not resp:
# -> 1302                     raise e
#    1303
#    1304             if resp:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_portalpy.py in get_properties(self, force)
#    1280             resp = None
#    1281             try:
# -> 1282                 resp = self.con.post(path, self._postdata(), ssl=True)
#    1283             except Exception as e:
#    1284                 if (
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1517             )
#    1518         except Exception as e:
# -> 1519             raise Exception("A general error occurred: %s" % e)
#    1520         except:
#    1521             import traceback
#
# Exception: A general error occurred: Expecting ',' delimiter: line 1 column 669 (char 668)

# %%
df2 = analyzer.get_sorted_user_details()
df2
# Out:
#                      username last_login_date                 full_name  \
# 0                 boneill.aid      2023-08-17           Brendan O'Neill
# 1                kmorrish_dev      2023-08-18             Keera Morrish
# 2                   ckwon_aid      2023-08-09               Calvin Kwon
# 3               dgadsden_aid2      2022-12-01             David Gadsden
# 4              ralouta.aiddev      2023-08-18               Rami Alouta
# 5         apfister_EsriAidDev      2023-08-02              Adam Pfister
# 6                cbrigham_aid      2023-05-13           Charles Brigham
# 7               cterborgh_aid      2023-08-17         Carmelle Terborgh
# 8               AidDevService      2023-08-18         Aid & Development
# 9                 ssawaya_aid      2023-06-20              Salim Sawaya
# 10        ajenkins_EsriAidDev      2023-08-17              Adam Jenkins
# 11         bstayer_EsriAidDev      2022-07-13             Bonnie Stayer
# 12             amakowicki_aid      2022-08-02          Andrew Makowicki
# 13                 ksmyth_aid      2023-02-02           Katherine Smyth
# 14         ckiefer_EsriAidDev      2020-07-29               Cody Kiefer
# 15             cmesserich_aid      2023-08-17           Chris Messerich
# 16                  khess_aid      2020-10-28                 Kate Hess
# 17                akim.aiddev      2023-08-18                   Ari Kim
# 18         lczerwinski.aiddev      2023-07-28         Lukasz Czerwinski
# 19        ESwenson_EsriAidDev      2023-08-18             Emily Swenson
# 20               testuser_aid      2020-04-24                 Test User
# 21        tbutcher_EsriAidDev      2023-07-26            Travis Butcher
# 22        dkochhar_EsriAidDev      2023-07-11            Deepti Kochhar
# 23         mburger_EsriAidDev      2018-05-10             Marius Burger
# 24                ltodd.eadev      2022-10-28                  Liz Todd
# 25              bmccardle_aid      2021-10-01          Brianna McCardle
# 26                 AGiron_aid      2021-12-29              Amanda Giron
# 27              mmusgrave_aid      2023-08-11          Madison Musgrave
# 28                 EsriAidDev      2019-01-29  Esri Aid and Development
# 29                RLehman_aid      2020-07-13            Rebecca Lehman
# 30         croland_EsriAidDev      2022-09-15           Christie Roland
# 31                jmunyao.aid      2020-09-01             Joseph Munyao
# 32        hturvene_EsriAidDev      2023-02-02             Helen Turvene
# 33  jvaughangibson_EsriAidDev      2020-06-11   Jennifer Vaughan-Gibson
# 34          slibby_EsriAidDev      2022-02-15                 Sam Libby
# 35                  katia.aid      2020-02-25       Katia Valenza-Lyons
# 36                  toaks_aid      2022-11-14                 Thom Oaks
# 37             jvandeusen_aid      2020-07-12            Jen Van Deusen
# 38            ckwon_aidviewer      2021-03-03               Calvin Kwon
#
#                            email  item_count  total_credits  \
# 0               boneill@esri.com          74     855.273838
# 1              kmorrish@esri.com          64     431.596659
# 2                 ckwon@esri.com          69     120.639378
# 3              dgadsden@esri.com          40      56.185800
# 4               ralouta@esri.com          31      44.397836
# 5              apfister@esri.com          65      26.970911
# 6              cbrigham@esri.com          76       9.147158
# 7             cterborgh@esri.com          55       8.927406
# 8              apfister@esri.com           5       5.799796
# 9               ssawaya@esri.com          41       5.438300
# 10         Adam_Jenkins@esri.com          64       5.010455
# 11              bstayer@esri.com          27       4.677505
# 12           amakowicki@esri.com          20       2.012076
# 13               ksmyth@esri.com           5       1.427873
# 14              ckiefer@esri.com           3       1.330210
# 15           cmesserich@esri.com           1       0.655094
# 16                khess@esri.com           2       0.462422
# 17                 akim@esri.com           4       0.314910
# 18          lczerwinski@esri.com           5       0.232332
# 19             ESwenson@esri.com          15       0.190997
# 20                ckwon@esri.com           2       0.180929
# 21             tbutcher@esri.com          12       0.168002
# 22             dkochhar@esri.com           9       0.142141
# 23  mburger@esri-southafrica.com           3       0.120615
# 24                ltodd@esri.com           3       0.047716
# 25            bmccardle@esri.com           5       0.046906
# 26               AGiron@esri.com           5       0.036376
# 27            mmusgrave@esri.com           5       0.035966
# 28              boneill@esri.com          69       0.023768
# 29              RLehman@esri.com           1       0.009437
# 30              croland@esri.com           3       0.006205
# 31              jmunyao@esri.com          12       0.003524
# 32             hturvene@esri.com           4       0.001515
# 33      JVaughan-Gibson@esri.com           3       0.001340
# 34               slibby@esri.com           2       0.000787
# 35              boneill@esri.com           3       0.000702
# 36                toaks@esri.com           2       0.000414
# 37           jvandeusen@esri.com           1       0.000223
# 38                ckwon@esri.com           1       0.000121
#
#     total_item_size_mb  total_cost_per_month
# 0          3563.640992             85.527384
# 1          1798.319411             43.159666
# 2           502.664076             12.063938
# 3           234.107502              5.618580
# 4           184.990982              4.439784
# 5           112.378795              2.697091
# 6            38.113158              0.914716
# 7            37.197527              0.892741
# 8            24.165817              0.579980
# 9            22.659584              0.543830
# 10           20.876895              0.501045
# 11           19.489603              0.467750
# 12            8.383652              0.201208
# 13            5.949471              0.142787
# 14            5.542542              0.133021
# 15            2.729558              0.065509
# 16            1.926758              0.046242
# 17            1.312126              0.031491
# 18            0.968049              0.023233
# 19            0.795820              0.019100
# 20            0.753870              0.018093
# 21            0.700006              0.016800
# 22            0.592256              0.014214
# 23            0.502561              0.012061
# 24            0.198815              0.004772
# 25            0.195443              0.004691
# 26            0.151566              0.003638
# 27            0.149859              0.003597
# 28            0.099035              0.002377
# 29            0.039322              0.000944
# 30            0.025852              0.000620
# 31            0.014682              0.000352
# 32            0.006314              0.000152
# 33            0.005585              0.000134
# 34            0.003280              0.000079
# 35            0.002927              0.000070
# 36            0.001725              0.000041
# 37            0.000930              0.000022
# 38            0.000505              0.000012

# %%
df3 = analyzer.get_users_before_target_date()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17028\196859353.py in <cell line: 1>()
# ----> 1 df3 = analyzer.get_users_before_target_date()
#
# ~\AppData\Local\Temp\ipykernel_17028\2112679596.py in get_users_before_target_date(self)
#     137
#     138         # Get the sorted user details
# --> 139         sorted_user_details = self.get_sorted_user_details()
#     140
#     141         # Initialize a list to store usernames with dates before the adjusted_target_date
#
# TypeError: get_sorted_user_details() missing 1 required positional argument: 'items_df'

# %%
class CreateFeatureLayer:
    def __init__(self, analyzer: ArcGISDataAnalyzer):
        self.gis = GIS("https://esriaiddev.maps.arcgis.com/", "ralouta.aiddev", "RamiW0rk$@esri0316")  # Initialize the GIS instance
        self.analyzer = analyzer
        self.layer_name = "ArcGIS Items and Users Management"

    def create_feature_layer(self):
        # Check if feature layer with the specified name exists in ArcGIS Online
        search_results = self.gis.content.search(query=self.layer_name, item_type="Feature Layer")
        if search_results:
            # Delete the existing feature layer
            for item in search_results:
                item.delete()

        # Create a new feature layer collection
        flc = self.gis.content.create_feature_layer_collection(self.layer_name)

        # Add the three sublayers to the feature layer collection
        flc.manager.add_to_definition({
            "name": "items_before_date_all_users",
            "type": "Feature Layer",
            "fields": GeoAccessor.from_dataframe(self.analyzer.get_items_before_date_all_users()).fields,
            "source": self.analyzer.get_items_before_date_all_users().to_dict(orient="records")
        })
        flc.manager.add_to_definition({
            "name": "sorted_user_details",
            "type": "Feature Layer",
            "fields": GeoAccessor.from_dataframe(self.analyzer.get_sorted_user_details()).fields,
            "source": self.analyzer.get_sorted_user_details().to_dict(orient="records")
        })
        flc.manager.add_to_definition({
            "name": "users_before_target_date",
            "type": "Feature Layer",
            "fields": GeoAccessor.from_dataframe(self.analyzer.get_users_before_target_date()).fields,
            "source": self.analyzer.get_users_before_target_date().to_dict(orient="records")
        })

        # Publish the feature layer collection
        flc.manager.publish()

        return flc.url

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17972\1703086614.py in <cell line: 1>()
# ----> 1 df2 = analyzer.get_sorted_user_details()
#
# ~\AppData\Local\Temp\ipykernel_17972\1799995977.py in get_sorted_user_details(self)
#      90         items_before_date_all_users_df = self.items_before_date_all_users_df
#      91         # Extract unique usernames
# ---> 92         unique_usernames = items_before_date_all_users_df['username'].unique()
#      93
#      94         # Group the DataFrame by 'username' and calculate the total counts of items owned by each user
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df3 = analyzer.get_users_before_target_date()

# Create an instance of the CreateFeatureLayer class
feature_layer_creator = CreateFeatureLayer(analyzer)

# Create the feature layer
feature_layer_url = feature_layer_creator.create_feature_layer()

# Print the URL of the feature layer
print(f"Feature layer URL: {feature_layer_url}")
